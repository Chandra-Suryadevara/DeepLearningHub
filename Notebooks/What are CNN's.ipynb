# %% [markdown]
# ### Convolutional neural network

# %% [markdown]
# Let's Firsst Breakdown CNN into
# 1. Tensors
# 2. DNN vs CNN
# 3. Convolutions and Filters
# 4. Padding
# 5. Pooling Layers
# 6. Review Dropout

# %% [markdown]
# ### Tensors

# %% [markdown]
# Tensors are N-Dimensional Arrays
# Example
# * Scalar - 3
# * Vector - [3,2,4]
# * Matrix = [[3,4],[5,6]]
# * Tensor = [[1,2],[3,4]],[[5,6],[7,8]]]
# * Tensors are very convenient to feed the images or data into a model.

# %% [markdown]
# ### DNN vs CNN

# %% [markdown]
# ![image.png](attachment:c1cf8fe7-a6ce-47df-a12b-90de05b33939.png)

# %% [markdown]
# * If we have dense connected neural network it is going to have so many parameter even for a 256 pixels iamge but when it comes to Convolutional Neural Network it only have limited and less than DNN which makes the model simple and fast

# %% [markdown]
# * Convolutions also have major advantage for iamge processing where pixels nearby coorelate to each other and it is really helpful for image detection

# %% [markdown]
# ![imageedit_1_9340399710.gif](attachment:2b631dd1-5a57-4e91-b48f-3d23ea7279cf.gif)

# %% [markdown]
# * There is a small issue here cause as we get to edge there may not be neurons on edge so do padding basically giving zeros to neigbour neurons on edges which is called **padding**

# %% [markdown]
# ### 1-D Convolution

# %% [markdown]
# ![Screenshot from 2024-06-24 16-00-10.png](attachment:d79e3916-8fe0-4f22-a213-c2fbe2df6d8f.png)

# %% [markdown]
# Lets say our input are X1, X2
#
# so when we add those weights to it y=w1*x1+w2*x2
# so th is values is stored or passed to layer 2 This is a filter

# %% [markdown]
# ![Screenshot from 2024-06-24 16-11-35.png](attachment:79530105-ef93-41b1-80df-ee806c7ee653.png)

# %% [markdown]
# Filter Size is 2 cause we have two weights and strides are basically we are moving up weights every two neuronsis called stride

# %% [markdown]
# ![image.png](attachment:fa47654d-9d65-4345-aff8-7aa6d904adb1.png)

# %% [markdown]
# ![image.png](attachment:690b64ce-83a5-4cb5-b50b-647f74cee2d1.png)

# %% [markdown]
# ### 2D- Convolution

# %% [markdown]
# * With 2D we are mainly dealing with images
# * Instead of 1D data now we have 2d example Height and width of the image
# * Also Stride distance also desides how a=fast are going to move across the image while we are filtering

# %% [markdown]
# ![Screenshot from 2024-06-24 16-24-12.png](attachment:593a2178-c05f-41db-a935-b39816fefda8.png)

# %% [markdown]
# * move the filter by 1 pixel

# %% [markdown]
# ![Screenshot from 2024-06-24 16-24-56.png](attachment:b3a85e59-1f41-4b6b-8810-af0eace6b3c9.png)

# %% [markdown]
# * Here we are moving the filter over by two pixels then applying those changes

# %% [markdown]
# ### Sub Sampling OR Pooling

# %% [markdown]
# * So pooling sub samples the input image , Which reduces the memory use and computer load as well as reducing number of parameters

# %% [markdown]
# ![image.png](attachment:5391abe3-47fc-482e-b14a-59b00c28afb4.png)

# %% [markdown]
# * And in here we took 2x2 which is kernal size
# * Also Pooling layer will end up removing a lot of information , even a small pooling 2x2 kernal can remove 75% of input data

# %% [markdown]
# ### Dropout

# %% [markdown]
# * It is the process regularization to help prevent overfitting
# * During training units are randomly dropped, along with their connections.
# * This helps prevents units from coadapting too much.
